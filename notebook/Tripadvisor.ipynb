# %%
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import asyncio
from tqdm.notebook import tqdm

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# %%
#TRIPADVISOR:

PATH = "driver/chromedriver.exe"
driver = webdriver.Chrome()

url='https://www.tripadvisor.es/FindRestaurants?geo=187514&cuisines=10749%2C10639%2C10659%2C4617%2C5473%2C10653%2C5110%2C5379%2C10698%2C10631%2C10715%2C10772%2C5086%2C20076%2C10687%2C10346%2C10660%2C20062%2C10622%2C10757%2C10661%2C20069%2C10348%2C10347%2C10626%2C10791%2C10633%2C10692%2C20066%2C10680%2C10744%2C10632%2C10752%2C20068%2C20067%2C11744%2C10618%2C11739%2C10769%2C10742%2C10765%2C10753%2C10732%2C10635%2C10767%2C10662%2C10693%2C10695%2C10664%2C10636%2C10617%2C10628%2C21363%2C10675%2C20074%2C10696%2C10748%2C10756%2C10690%2C10681%2C10717%2C10747%2C10784%2C10775%2C10766%2C10755&establishmentTypes=10591&broadened=false'
driver.get(url)

# %%
# cookies:
 
time.sleep(2)

aceptar=driver.find_element(By.XPATH,'//*[@id="onetrust-accept-btn-handler"]')

aceptar.click()

# %%
#nombre1:
nombres=driver.find_elements(By.XPATH,'//div[@class="biGQs _P fiohW alXOW NwcxK GzNcM ytVPx UTQMg RnEEZ ngXxk"]')
names=[elementos.text for elementos in nombres]

# %%
#tarjetas:

# esto es una caja con todos los datos dentro: driver.find_elements(By.TAG_NAME,'header')[1].text.split('\n')

tarjetas=[]
for e in range(len(driver.find_elements(By.TAG_NAME,'header'))):
               
    box=driver.find_elements(By.TAG_NAME,'header')[e].text.split('\n')
    tarjetas.append(box)

# %%
tabla=pd.DataFrame(tarjetas)   # aqui ya me guarda la primera página en una tabla  HELLO WORLD

# %%
tabla
# Out:
#                                0                                1  \
# 0                      Descubrir                           Viajes
# 1          1. Pizzart Fuencarral       897 opinionesAbierto ahora
# 2                    2. Maximo's       267 opinionesCerrado ahora
# 3           3. Ornella Velázquez  2282 opinionesAbre en 6 minutos
# 4                    4. Smok Mok       103 opinionesAbierto ahora
# 5                  5. Maruzzella       960 opinionesCerrado ahora
# 6   6. Lettera Trattoria moderna      1554 opinionesCerrado ahora
# 7                 7. Malafemmena  1509 opinionesAbre en 6 minutos
# 8        8. Trattoria Pulcinella  2766 opinionesAbre en 6 minutos
# 9          9. Gustazio Gastrobar       235 opinionesCerrado ahora
# 10     10. Davanti Food & Market       412 opinionesCerrado ahora
# 11                      MICHELIN        11. Restaurante Pura Vida
# 12   12. Pizzart Villa Canalejas       898 opinionesAbierto ahora
# 13              13. Ouh...Babbo!         664 opinionesCerrado hoy
# 14            14. Piccola Napoli       499 opinionesCerrado ahora
# 15              15. Sushi Tokami        65 opinionesCerrado ahora
# 16                 16. Pastamore      1012 opinionesAbierto ahora
